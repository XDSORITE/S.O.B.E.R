# %%
import torch

# Check if CUDA (GPU support) is available on the Colab server
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"Success! Connected to Cloud GPU: {torch.get_device_name(0)}")
else:
    print("GPU not found. Training will run on CPU. Check your Colab runtime settings.")
# Out:
# GPU not found. Training will run on CPU. Check your Colab runtime settings.
